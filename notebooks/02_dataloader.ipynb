# %% [markdown]
# # DataLoader
#
# ## Objective
#
# In this notebook we verify that the custom DataLoader correctly loads batches of low-resolution and high-resolution image patches for training.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.dataloader import get_train_loader

# %%
train_loader = get_train_loader()

print(train_loader)

# %%
for lr_batch, hr_batch in train_loader:

    print(lr_batch.shape)
    print(hr_batch.shape)

    break
# Out:
# torch.Size([16, 3, 96, 96])
# torch.Size([16, 3, 96, 96])
