# %% [markdown]
# # SRCNN Model
#
# ## Objective
#
# In this notebook we verify the implementation of the SRCNN architecture.
#
# The objectives are:
#
# - instantiate the model;
# - inspect the network architecture;
# - perform a forward pass;
# - verify that the input and output dimensions are consistent.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.models.srcnn import SRCNN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.models.srcnn import SRCNN
#
# File c:\Users\aless\Documents\RetroSR-CNN\src\models\srcnn.py:11
#       1 """
#       2 SRCNN model implementation.
#       3
#    (...)
#       6 Image Super-Resolution Using Deep Convolutional Networks (ECCV 2014)
#       7 """
#       9 import torch.nn as nn
# ---> 11 class SRCNN(nn.Module):
#      12     def __init__(self):
#      13         super().__init__()
#
# File c:\Users\aless\Documents\RetroSR-CNN\src\models\srcnn.py:15, in SRCNN()
#      12     def __init__(self):
#      13         super().__init__()
# ---> 15     self.feature_extraction = nn.Sequential(
#      16
#      17     nn.Conv2d(
#      18         in_channels=3,
#      19         out_channels=64,
#      20         kernel_size=9,
#      21         padding=4
#      22     ),
#      23
#      24     nn.ReLU(inplace=True)
#      25 )
#      26     self.mapping = nn.Sequential(
#      27
#      28     nn.Conv2d(
#    (...)
#      34     nn.ReLU(inplace=True)
#      35 )
#      36     self.reconstruction = nn.Conv2d(
#      37
#      38     in_channels=32,
#    (...)
#      41     padding=2
#      42 )
#
# NameError: name 'self' is not defined

# %% [markdown]
# ## Instantiate the model
#
# Create an instance of the SRCNN architecture.

# %%
model = SRCNN()

print(model)

# %% [markdown]
# ## Number of trainable parameters
#
# Compute the total number of trainable parameters of the model.

# %%
num_params = sum(p.numel() for p in model.parameters())

print(f"Trainable parameters: {num_params:,}")

# %% [markdown]
# ## Forward pass
#
# Verify that the model accepts a batch of images and produces an output having the expected dimensions.

# %%
from src.dataloader import get_train_loader

# %%
train_loader = get_train_loader()

# %%
lr_batch, hr_batch = next(iter(train_loader))

print(lr_batch.shape)
print(hr_batch.shape)

# %%
output = model(lr_batch)

print(output.shape)

# %% [markdown]
# ## Conclusions
#
# The SRCNN architecture was successfully instantiated.
#
# The forward pass confirms that:
#
# - the model accepts batches of RGB images;
# - the output resolution matches the target resolution;
# - the implementation is ready for training.
